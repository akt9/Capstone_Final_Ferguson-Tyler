# %% [markdown]
# # sentiment analysis of articles that mention the suspects
#
# at this stage, we decided to start putting the pieces together. we used a few libraries from nltk to begin processing out the relevant articles from our suspect list and started digging into the articles by hand to put together the full story

# %% [markdown]
# ### import statements
#
# lots of pandas and tools to help us iterate through the articles, in addition to nltk for scraping and sentiment analysis

# %%
import pandas as pd
import os
import chardet
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.tag import pos_tag
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
nltk.download('wordnet')

pd.set_option('display.max_rows', 20)

# %% [markdown]
# ### user defined functions
#
# here we set up a few functions (and borrowed others from elsewhere within our code) to begin parsing the articles

# %%
### function top combine the first and last name into a new column, in case the 
### person is mentioned using their first and last names in the article
def combine_names(df):
    df['Name'] = df['FirstName'] + ' ' + df['LastName']
    return df

### function to crank through the dataframe and compose a new dataframe including 
### the sentiment, the article, the relevant bag of words and the person. 
### returns a new df with all listed elements
def analyze_files_for_sentiment(folder_path, individuals_df, column_name):
    sia = SentimentIntensityAnalyzer()
    results = []

    for file in os.listdir(folder_path):
        if file.endswith('.txt'):
            with open(os.path.join(folder_path, file), 'rb') as f:
                raw_data = f.read()
                encoding = chardet.detect(raw_data)['encoding']
                text = raw_data.decode(encoding)

            tokens = word_tokenize(text)
            tokens = [t for t in tokens if t.lower() not in stopwords.words('english')]

            for item in individuals_df[column_name]:
                sentiment = 0
                count = 0
                keywords = set()

                for token in tokens:
                    if item.lower() in token.lower():
                        sentences = sent_tokenize(text)
                        for sentence in sentences:
                            if token in sentence:
                                tagged_sentence = pos_tag(word_tokenize(sentence))

                                for word, tag in tagged_sentence:
                                    if tag.startswith('N') and wordnet.synsets(word):
                                        keywords.add(word)

                                sentiment += sia.polarity_scores(sentence)['compound']
                                count += 1

                if count > 0:
                    results.append((file, item, round(sentiment/count, 2), list(keywords)))

    df = pd.DataFrame(results, columns=['File Name', 'Entity', 'Sentiment Score', 'Keywords'])

    return df


### function to create a frequency assessment of different words to help us zero in on
### words of interest related to our subjects
def count_list_items(df_col):
    all_items = [item.lower() for sublist in df_col for item in sublist]

    freq_dict = {}
    for item in all_items:
        if item in freq_dict:
            freq_dict[item] += 1
        else:
            freq_dict[item] = 1

    sorted_freq = sorted(freq_dict.items(), key=lambda x: x[1], reverse=True)

    for item, freq in sorted_freq:
        print(f"{item}: {freq}")

# %% [markdown]
# ### creating the sentiment dataframe on the suspected gastech employees
#
# we process the suspects using the above functions to create a dataframe that we can later use to parse through the relevant articles

# %%
suspects_df = pd.read_csv('suspects_frame.csv')

suspects_df = combine_names(suspects_df)

display(suspects_df)
# Out:
#    Unnamed: 0    LastName FirstName   BirthDate BirthCountry  Gender  \
# 0           0  Mies Haber  Ruscella  1964-04-26       Kronos  Female
# 1          17        Vann      Isia  1986-12-13       Kronos    Male
# 2          19     Bodrogi    Loreto  1989-04-17       Kronos    Male
# 3          20    Cocinaro    Hideki  1980-12-25       Tethys    Male
# 4          21     Osvaldo    Hennie  1988-05-31       Kronos    Male
# 5          23        Mies     Minke  1992-11-19       Kronos    Male
# 6          26       Ferro      Inga  1989-06-17       Kronos  Female
# 7          52     Herrero     Kanon  1984-10-03       Tethys    Male
# 8          53       Lagos     Varja  1976-05-01       Tethys  Female
#
#   CitizenshipCountry CitizenshipBasis CitizenshipStartDate PassportCountry  \
# 0             Kronos      BirthNation           1964-04-26             NaN
# 1             Kronos      BirthNation           1986-12-13             NaN
# 2             Kronos      BirthNation           1989-04-17             NaN
# 3             Tethys      BirthNation           1980-12-25          Tethys
# 4             Kronos      BirthNation           1988-05-31             NaN
# 5             Kronos      BirthNation           1992-11-19             NaN
# 6             Kronos      BirthNation           1989-06-17             NaN
# 7             Tethys      BirthNation           1984-10-03          Tethys
# 8             Tethys      BirthNation           1976-05-01          Tethys
#
#   PassportIssueDate PassportExpirationDate CurrentEmploymentType  \
# 0               NaN                    NaN        Administration
# 1               NaN                    NaN              Security
# 2               NaN                    NaN              Security
# 3        2013-05-25             2023-05-24              Security
# 4               NaN                    NaN              Security
# 5               NaN                    NaN              Security
# 6               NaN                    NaN              Security
# 7        2008-10-10             2018-10-09              Security
# 8        2013-07-07             2023-07-06              Security
#
#                    CurrentEmploymentTitle CurrentEmploymentStartDate  \
# 0  Assistant to Engineering Group Manager                 2003-04-02
# 1                       Perimeter Control                 2007-12-14
# 2                            Site Control                 2013-08-17
# 3                            Site Control                 2010-01-01
# 4                       Perimeter Control                 2011-06-07
# 5                       Perimeter Control                 2013-05-22
# 6                            Site Control                 2013-01-11
# 7                          Badging Office                 2008-11-20
# 8                          Badging Office                 2006-10-01
#
#                              EmailAddress   MilitaryServiceBranch  \
# 0  Ruscella.Mies.Haber@gastech.com.kronos     ArmedForcesOfKronos
# 1            Isia.Vann@gastech.com.kronos     ArmedForcesOfKronos
# 2       Loreto.Bodrogi@gastech.com.kronos     ArmedForcesOfKronos
# 3      Hideki.Cocinaro@gastech.com.kronos  TethanDefenseForceArmy
# 4       Hennie.Osvaldo@gastech.com.kronos     ArmedForcesOfKronos
# 5           Minke.Mies@gastech.com.kronos     ArmedForcesOfKronos
# 6           Inga.Ferro@gastech.com.kronos     ArmedForcesOfKronos
# 7        Kanon.Herrero@gastech.com.kronos                     NaN
# 8          Varja.Lagos@gastech.com.kronos                     NaN
#
#   MilitaryDischargeType MilitaryDischargeDate                 Name
# 0    HonorableDischarge            1984-10-01  Ruscella Mies Haber
# 1      GeneralDischarge            2007-10-01            Isia Vann
# 2    HonorableDischarge            2008-10-01       Loreto Bodrogi
# 3    HonorableDischarge            2009-10-01      Hideki Cocinaro
# 4      GeneralDischarge            2010-10-01       Hennie Osvaldo
# 5      GeneralDischarge            2011-10-01           Minke Mies
# 6      GeneralDischarge            2012-10-01           Inga Ferro
# 7                   NaN                   NaN        Kanon Herrero
# 8                   NaN                   NaN          Varja Lagos

# %%
try:
    folder_path = 'C:/Users/Andy/PycharmProjects/pythonProject/The_Last_Stand/TP-1_Kronos/articles'
    column_name = 'FirstName'
    firstName_df = analyze_files_for_sentiment(folder_path, suspects_df, column_name)
except:
    folder_path = 'C:/Users/andyt/PycharmProjects/classworker_General/The_Last_Stand/TP-1_Kronos/articles'
    column_name = 'FirstName'
    firstName_df = analyze_files_for_sentiment(folder_path, suspects_df, column_name)

# display(firstName_df)

# %%
try:
    folder_path = 'C:/Users/Andy/PycharmProjects/pythonProject/The_Last_Stand/TP-1_Kronos/articles'
    column_name = 'LastName'
    lastName_df = analyze_files_for_sentiment(folder_path, suspects_df, column_name)
except:
    folder_path = 'C:/Users/andyt/PycharmProjects/classworker_General/The_Last_Stand/TP-1_Kronos/articles'
    column_name = 'LastName'
    lastName_df = analyze_files_for_sentiment(folder_path, suspects_df, column_name)

# display(lastName_df)

# %%
sentiment_df = pd.concat([firstName_df, lastName_df], axis=0)

pd.set_option('display.max_rows', None)

display(sentiment_df)

sentiment_df.to_csv('sentiment_df.csv')
# Out:
#     File Name   Entity  Sentiment Score  \
# 0       2.txt     Inga             0.53
# 1     241.txt     Isia            -0.79
# 2     302.txt     Inga             0.48
# 3     377.txt     Isia            -0.80
# 4     443.txt     Inga             0.66
# 5      48.txt     Isia            -0.86
# 6     578.txt     Isia            -0.86
# 7     690.txt     Isia            -0.86
# 8     701.txt     Inga            -0.22
# 9     756.txt     Isia            -0.86
# 10    762.txt     Inga             0.66
# 0       0.txt     Vann            -0.25
# 1     107.txt     Vann             0.10
# 2     116.txt     Vann             0.48
# 3     116.txt  Bodrogi             0.00
# 4     125.txt     Vann            -0.75
# 5     129.txt     Vann            -0.80
# 6     130.txt     Vann             0.00
# 7     132.txt     Vann            -0.49
# 8     134.txt  Bodrogi             0.00
# 9     140.txt     Vann            -0.32
# 10    145.txt     Vann            -0.07
# 11    149.txt     Vann            -0.90
# 12    154.txt  Bodrogi            -0.24
# 13    154.txt  Osvaldo            -0.48
# 14    155.txt     Vann            -0.93
# 15    161.txt     Vann            -0.73
# 16    173.txt     Vann            -0.40
# 17    175.txt     Vann            -0.74
# 18     18.txt     Vann            -0.18
# 19     18.txt  Bodrogi             0.00
# 20    183.txt  Bodrogi            -0.09
# 21    183.txt    Ferro            -0.48
# 22    187.txt  Bodrogi            -0.12
# 23    189.txt     Vann             0.51
# 24    197.txt     Vann            -0.23
# 25    205.txt  Bodrogi            -0.82
# 26    211.txt  Bodrogi             0.00
# 27    217.txt     Vann            -0.84
# 28    217.txt  Bodrogi            -0.76
# 29    225.txt     Vann            -0.73
# 30    237.txt  Bodrogi             0.00
# 31     24.txt     Vann            -0.91
# 32    248.txt     Vann            -0.81
# 33    248.txt  Osvaldo            -0.41
# 34    249.txt     Vann            -0.83
# 35    255.txt  Bodrogi            -0.98
# 36    263.txt     Vann            -0.72
# 37    264.txt  Bodrogi             0.42
# 38    268.txt     Vann            -0.89
# 39    269.txt     Vann            -0.61
# 40    273.txt     Vann            -0.80
# 41    275.txt     Vann            -0.72
# 42    282.txt     Vann            -0.78
# 43     29.txt     Vann            -0.21
# 44    290.txt     Vann            -0.95
# 45    293.txt     Vann            -0.13
# 46    300.txt     Vann            -0.42
# 47    317.txt  Bodrogi            -0.06
# 48    317.txt  Osvaldo            -0.48
# 49    318.txt     Vann             0.00
# 50    326.txt     Vann            -0.48
# 51    328.txt     Vann            -0.53
# 52     33.txt     Vann            -0.28
# 53    341.txt     Vann            -0.95
# 54    343.txt     Vann             0.36
# 55     35.txt  Bodrogi             0.00
# 56    351.txt     Vann             0.00
# 57    353.txt     Vann            -0.91
# 58    357.txt     Vann            -0.86
# 59    374.txt     Vann             0.00
# 60    387.txt     Vann            -0.86
# 61    391.txt  Bodrogi             0.00
# 62    394.txt     Vann             0.00
# 63    397.txt     Vann             0.10
# 64    399.txt  Bodrogi             0.00
# 65      4.txt  Bodrogi             0.00
# 66    400.txt     Vann            -0.35
# 67    408.txt  Bodrogi             0.00
# 68    409.txt     Vann            -0.72
# 69    412.txt     Vann            -0.02
# 70    431.txt     Vann             0.20
# 71    438.txt     Vann            -0.22
# 72    440.txt     Vann            -0.71
# 73    445.txt     Vann            -0.78
# 74    447.txt  Bodrogi            -0.70
# 75    448.txt  Bodrogi            -0.24
# 76    448.txt  Osvaldo            -0.48
# 77    450.txt    Lagos            -0.32
# 78    459.txt  Bodrogi             0.00
# 79    461.txt     Vann            -0.21
# 80    465.txt  Bodrogi             0.00
# 81    466.txt     Vann            -0.29
# 82    468.txt     Vann            -0.81
# 83    468.txt  Osvaldo            -0.41
# 84    469.txt     Vann            -0.48
# 85    482.txt     Vann            -0.56
# 86    482.txt  Osvaldo            -0.28
# 87     49.txt     Vann            -0.48
# 88    494.txt     Vann            -0.32
# 89     50.txt     Vann            -0.52
# 90    502.txt  Bodrogi            -0.01
# 91    502.txt    Ferro            -0.48
# 92    508.txt     Vann             0.44
# 93     51.txt     Vann            -0.56
# 94     51.txt  Bodrogi            -0.76
# 95    512.txt     Vann            -0.49
# 96    520.txt     Vann            -0.28
# 97    531.txt  Bodrogi            -0.24
# 98    531.txt  Osvaldo            -0.48
# 99    538.txt     Vann             0.36
# 100    54.txt     Vann            -0.56
# 101   544.txt     Vann            -0.80
# 102    55.txt     Vann            -0.28
# 103   554.txt     Vann            -0.88
# 104   570.txt     Vann            -0.18
# 105   572.txt     Vann             0.20
# 106   572.txt  Bodrogi             0.00
# 107   575.txt     Vann            -0.93
# 108   581.txt     Vann            -0.13
# 109   593.txt     Vann            -0.80
# 110   594.txt     Vann            -0.12
# 111   607.txt     Vann            -0.16
# 112   612.txt     Vann            -0.81
# 113   612.txt  Osvaldo            -0.81
# 114   620.txt     Vann             0.08
# 115   622.txt  Bodrogi             0.00
# 116   628.txt  Bodrogi             0.00
# 117   642.txt    Lagos             0.04
# 118   647.txt  Bodrogi             0.05
# 119   647.txt    Ferro            -0.48
# 120   662.txt     Vann             0.20
# 121   662.txt  Bodrogi             0.00
# 122   670.txt     Vann             0.40
# 123   673.txt     Vann            -0.48
# 124   674.txt     Vann            -0.54
# 125    69.txt  Bodrogi            -0.24
# 126    69.txt  Osvaldo            -0.48
# 127   696.txt  Bodrogi            -1.00
# 128   698.txt     Vann            -0.18
# 129   698.txt  Bodrogi             0.00
# 130     7.txt     Vann            -0.48
# 131   700.txt     Vann            -0.95
# 132   709.txt     Vann            -0.16
# 133   712.txt     Vann            -0.13
# 134    73.txt     Vann            -0.88
# 135   735.txt     Vann            -0.56
# 136   735.txt  Bodrogi            -0.76
# 137    74.txt     Vann            -0.23
# 138   740.txt     Vann            -0.87
# 139   740.txt  Osvaldo            -0.24
# 140   741.txt  Bodrogi             0.08
# 141   741.txt    Ferro            -0.48
# 142   743.txt     Vann            -0.74
# 143   743.txt  Bodrogi            -0.70
# 144   753.txt     Vann            -0.28
# 145   761.txt     Vann            -0.22
# 146   767.txt     Vann             0.44
# 147   769.txt     Vann            -0.95
# 148    77.txt     Vann            -0.73
# 149   791.txt     Vann            -0.13
# 150   794.txt     Vann            -0.49
# 151   799.txt     Vann            -0.62
# 152   814.txt  Bodrogi             0.00
# 153   818.txt     Vann             0.03
# 154   833.txt     Vann            -0.95
# 155   839.txt  Bodrogi            -0.99
#
#                                               Keywords
# 0    [answer, equipment, CARE, TOOK, conflict, miss...
# 1    [members, accident, government, results, ACCID...
# 2    [conflict, Turkey, group, Singapore, teams, ta...
# 3    [error, members, accident, government, conduct...
# 4    [care, conflict, missions, Turkey, group, Sing...
# 5    [error, members, accident, government, Speaks,...
# 6    [International, ABILA, NEAR, TRAFFIC, error, m...
# 7    [International, ABILA, NEAR, TRAFFIC, error, m...
# 8    [assistance, WORRYING, conflict, missions, Tur...
# 9    [International, ABILA, NEAR, TRAFFIC, error, m...
# 10   [care, conflict, missions, Turkey, group, Sing...
# 0    [posters, chiefs, water, drinking, toxins, tol...
# 1    [hours, protectors, protector, security, today...
# 2    [members, neighbor, sickness, friends, family,...
# 3                   [attention, founder, father, pace]
# 4    [guard, members, hours, RELEASED, evening, EMP...
# 5    [members, death, year, group, signs, Protector...
# 6    [crowd, building, pictures, signs, front, Capi...
# 7       [year, giant, points, Images, girl, illnesses]
# 8    [drilling, Illumination, gas, pollution, group...
# 9    [guard, indication, safety, guards, events, to...
# 10   [members, knowledge, hours, name, implication,...
# 11   [countryside, May, road, diseases, year, jets,...
# 12   [soybeans, making, purchases, father, store, f...
# 13   [making, purchases, store, tractor, hardware, ...
# 14   [jail, image, corporation, streams, Protectors...
# 15   [Station, water, Yesterday, photographs, benze...
# 16   [police, declaration, customer, construction, ...
# 17   [police, water, Yesterday, photographies, toxi...
# 18   [members, neighbor, friends, family, illness, ...
# 19                             [path, founder, father]
# 20   [purchase, father, chatter, rise, container, b...
# 21   [purchases, city, motor, rise, hardware, tractor]
# 22   [task, introduce, minister, gas, year, polluti...
# 23   [Greater, crowd, samples, building, pictures, ...
# 24   [press, members, nobodies, protector, group, i...
# 25   [CROSSWALK, LIGHT, NOT, POISONING, INCORRECT, ...
# 26                                    [meeting, Chief]
# 27                            [sickness, water, years]
# 28                                  [health, position]
# 29   [Station, water, Yesterday, photographs, benze...
# 30                                               [man]
# 31   [jail, May, headquarters, corporation, year, s...
# 32   [maid, gas, year, refers, leukemia, benzene, p...
# 33   [maid, forwards, year, refers, leukemia, benze...
# 34   [martyrdom, police, maid, Yesterday, photograp...
# 35   [LIGHT, Speaks, DELIVER, NOT, PRONE, POLICE, O...
# 36   [friends, POISONING, DIES, Today, News, OLD, G...
# 37                                        [above, man]
# 38   [May, put, person, birthday, streams, dam, fun...
# 39            [illegal, friend, company, toxin, years]
# 40   [members, death, year, group, signs, Protector...
# 41   [Orb, WOMEN, friends, YEARS, POISONING, MATRIC...
# 42      [year, giant, points, Images, girl, illnesses]
# 43   [members, knowledge, hours, name, kidnapping, ...
# 44   [girl, item, water, drinking, year, benzene, p...
# 45             [yesterday, family, afternoon, friends]
# 46   [contamination, water, disease, doctors, girl,...
# 47   [soybeans, parents, warehouse, purchases, fath...
# 48     [warehouse, purchases, city, hardware, tractor]
# 49       [dies, person, pictures, birthday, aim, girl]
# 50   [guard, hours, perpetrators, indication, secur...
# 51   [members, protectors, samples, water, group, a...
# 52   [Posters, innocents, reminders, water, drinkin...
# 53   [girl, item, water, drinking, year, benzene, p...
# 54   [diseases, giant, points, meeting, girl, image...
# 55                                               [man]
# 56   [diseases, year, giant, points, gathering, ima...
# 57   [jail, May, headquarters, corporation, year, s...
# 58          [years, friend, company, toxin, poisoning]
# 59   [crowd, building, pictures, signs, front, Capi...
# 60   [jail, May, campaign, corporation, diseases, h...
# 61   [drilling, Illumination, gas, pollution, group...
# 62                       [Capitol, martyrs, sign, mob]
# 63   [instructions, hours, protectors, protector, s...
# 64           [meeting, Illumination, leader, Homeland]
# 65   [soybeans, bit, years, bolts, fathers, land, l...
# 66   [members, police, hours, example, name, connec...
# 67                                   [meeting, LEADER]
# 68   [Wrap, TEN, friends, YEARS, POISONING, MATRICE...
# 69   [police, person, January, BLOG, Rubicon, prote...
# 70   [members, hours, name, family, employee, share...
# 71   [police, January, Protectors, BLOG, similarity...
# 72   [hours, RELEASED, evening, EMPLOYEE, INTERROGA...
# 73   [parent, illegitimate, year, friend, company, ...
# 74                      [health, leadership, position]
# 75   [purchases, father, city, fathers, motor, life...
# 76   [purchases, city, motor, rise, hardware, tractor]
# 77   [Ms., incident, Strum, Uneasy, threat, Mr., bo...
# 78   [drilling, bases, minister, gas, pollution, gr...
# 79   [members, knowledge, hours, name, kidnapping, ...
# 80   [contamination, protectors, minister, gas, tow...
# 81   [servant, Speaks, RELEASED, ABILA, safety, mem...
# 82   [gas, year, refers, leukemia, operations, girl...
# 83   [Illumination, gas, year, Carmine, refers, leu...
# 84   [guard, hours, perpetrators, security, Protect...
# 85   [gas, year, refers, leukemia, benzene, operati...
# 86   [gas, year, refers, leukemia, benzene, traject...
# 87   [guard, hours, perpetrators, security, Protect...
# 88   [guard, safety, guards, events, today, criminals]
# 89   [RELEASED, January, ABILA, guard, members, eve...
# 90   [fields, purchase, making, father, container, ...
# 91   [Hardware, making, purchases, store, tractor, ...
# 92     [candles, pictures, signs, slogans, supporters]
# 93                 [operations, disease, water, years]
# 94              [control, direction, health, position]
# 95   [police, ABILA, QUESTIONED, guard, members, EM...
# 96   [posters, innocents, memories, drinking, water...
# 97   [purchases, father, store, fathers, material, ...
# 98               [store, material, tractor, purchases]
# 99   [martyrdoms, crowd, undulating, building, sign...
# 100  [contamination, water, doctors, girl, illness,...
# 101  [members, death, year, group, signs, Protector...
# 102  [posters, innocents, reminders, water, toxins,...
# 103         [years, friend, company, toxin, poisoning]
# 104  [members, neighbor, friends, family, illness, ...
# 105  [members, neighbor, friends, disease, family, ...
# 106                [walk, trajectory, founder, father]
# 107  [image, water, drinking, benzene, cancer, arti...
# 108        [candles, pictures, slogans, signs, strike]
# 109  [members, water, group, signs, Drilling, guard...
# 110  [surname, d, members, hours, kidnapping, emplo...
# 111  [members, knowledge, hours, name, removal, fam...
# 112  [gas, year, refers, leukemia, operations, girl...
# 113  [gas, year, refers, leukemia, operations, girl...
# 114       [candles, signs, slogans, defenders, images]
# 115                                              [man]
# 116                                  [meeting, leader]
# 117  [example, Strum, Uneasy, hung, call, Lagos, by...
# 118  [piece, purchase, father, package, soybeans, b...
# 119    [warehouse, purchases, city, hardware, tractor]
# 120  [members, neighbor, friends, disease, family, ...
# 121                       [walk, founder, father, way]
# 122  [samples, candles, favor, mottos, pictures, Ju...
# 123  [guard, hours, perpetrators, indication, secur...
# 124  [Breaking, police, Updates, Emergency, January...
# 125  [soybeans, making, purchases, father, store, f...
# 126  [making, purchases, store, tractor, hardware, ...
# 127  [CROSSWALK, WARRANT, LIGHT, November, DELIVER,...
# 128  [members, neighbor, friends, family, illness, ...
# 129                            [path, founder, father]
# 130  [guard, hours, perpetrators, indication, secur...
# 131  [water, benzene, picture, cancer, article, han...
# 132  [sickness, water, pollution, doctors, dawdling...
# 133    [guard, hours, security, events, today, guards]
# 134         [years, friend, company, toxin, poisoning]
# 135  [drilling, water, disease, operations, man, ye...
# 136                [control, bottom, health, position]
# 137  [contamination, maid, water, disease, doctors,...
# 138  [gas, year, refer, upstream, house, poisoning,...
# 139  [gas, year, refer, upstream, house, poisoning,...
# 140  [fields, purchase, father, container, bolt, to...
# 141              [store, material, tractor, purchases]
# 142                       [operations, illness, water]
# 143                     [health, leadership, position]
# 144  [Posters, innocents, reminders, water, drinkin...
# 145  [members, police, hours, name, kidnapping, nat...
# 146    [candles, pictures, signs, slogans, supporters]
# 147  [girl, water, drinking, benzene, eyes, picture...
# 148  [Station, water, Yesterday, photographs, benze...
# 149  [TEN, friends, evening, YEARS, Pegasus, OLD, D...
# 150  [members, water, birthday, group, signs, peopl...
# 151  [police, water, Yesterday, mail, benzene, June...
# 152                                              [man]
# 153  [guard, hours, indication, security, guards, e...
# 154  [girl, item, water, drinking, year, benzene, p...
# 155  [CROSSWALK, SUBMITTED, COUNTERFEITING, LEAVING...

# %% [markdown]
# ### bag of words
#
# we decided to include a bag of words to just see what kinds of things were being mentioned. this helps us back track to further pare down by articles that dont include words we want to see for relevance later

# %%
count_list_items(sentiment_df['Keywords'])
# Out:
# years: 40
# girl: 34
# members: 32
# water: 31
# abila: 30
# group: 27
# year: 25
# family: 24
# hours: 23
# police: 21
# employee: 19
# purchases: 18
# tractor: 18
# cancer: 17
# protectors: 16
# benzene: 16
# today: 15
# father: 15
# gas: 15
# drinking: 14
# front: 14
# hardware: 14
# government: 13
# security: 13
# guard: 13
# accident: 12
