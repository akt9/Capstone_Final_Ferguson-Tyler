# %% [markdown]
# # final suspect data generation
#
# so after reviewing the contents of the graph database, we found nine individuals who were highly likely to be involved in POK based on their email traffic and local nodes within the graph database. we wanted to be able to process this data along a few different avenues, so we broke those individuals out into set for further inspection against articles and other data

# %% [markdown]
# ### import statements

# %%
import pandas as pd

# %% [markdown]
# ### step 1: data pull

# %%
try:
    raw_df = pd.read_excel('C:/Users/Andy/PycharmProjects/pythonProject/The_Last_Stand/TP-1_Kronos/EmployeeRecords.xlsx')
except:
    raw_df = pd.read_excel('C:/Users/andyt/PycharmProjects/classworker_General/The_Last_Stand/TP-1_Kronos/EmployeeRecords.xlsx')

display(raw_df)
# Out:
#           LastName FirstName  BirthDate BirthCountry  Gender  \
# 0       Mies Haber  Ruscella 1964-04-26       Kronos  Female
# 1            Fusil    Stenig 1963-04-29       Tethys    Male
# 2            Balas     Felix 1960-03-04       Tethys    Male
# 3         Coginian     Dante 1971-12-01       Kronos    Male
# 4             Ovan  Bertrand 1964-12-12       Tethys    Male
# 5            Azada      Lars 1973-04-30       Tethys    Male
# 6          Resumir     Felix 1959-06-30       Tethys    Male
# 7          Hawelon    Benito 1978-11-23       Kronos    Male
# 8        Forluniau     Carla 1981-06-02       Kronos  Female
# 9           Morlun   Valeria 1981-09-22       Kronos  Female
# 10         Hawelon   Claudio 1983-08-13       Kronos    Male
# 11            Mies      Henk 1984-09-23       Kronos    Male
# 12          Morlun      Adan 1984-10-09       Kronos    Male
# 13            Nant     Irene 1985-03-13       Kronos  Female
# ...

# %% [markdown]
# ### pulling the suspects by email
#
# note we wrote this to csv for processing in other code blocks during article processing

# %%
suspects_df = raw_df.copy()

suspects = ['Loreto.Bodrogi@gastech.com.kronos', 
            'Minke.Mies@gastech.com.kronos',
            'Hennie.Osvaldo@gastech.com.kronos',
            'Ruscella.Mies.Haber@gastech.com.kronos',
            'Isia.Vann@gastech.com.kronos',
            'Inga.Ferro@gastech.com.kronos',
            'Varja.Lagos@gastech.com.kronos',
            'Hideki.Cocinaro@gastech.com.kronos',
            'Kanon.Herrero@gastech.com.kronos'
            ]

suspects_df = suspects_df[suspects_df['EmailAddress'].isin(suspects)]

display(suspects_df)

# suspects_df.to_csv('suspects_frame.csv')
# Out:
#       LastName FirstName  BirthDate BirthCountry  Gender CitizenshipCountry  \
# 0   Mies Haber  Ruscella 1964-04-26       Kronos  Female             Kronos
# 17        Vann      Isia 1986-12-13       Kronos    Male             Kronos
# 19     Bodrogi    Loreto 1989-04-17       Kronos    Male             Kronos
# 20    Cocinaro    Hideki 1980-12-25       Tethys    Male             Tethys
# 21     Osvaldo    Hennie 1988-05-31       Kronos    Male             Kronos
# 23        Mies     Minke 1992-11-19       Kronos    Male             Kronos
# 26       Ferro      Inga 1989-06-17       Kronos  Female             Kronos
# 52     Herrero     Kanon 1984-10-03       Tethys    Male             Tethys
# 53       Lagos     Varja 1976-05-01       Tethys  Female             Tethys
#
#    CitizenshipBasis CitizenshipStartDate PassportCountry PassportIssueDate  \
# 0       BirthNation           1964-04-26             NaN               NaT
# ...
